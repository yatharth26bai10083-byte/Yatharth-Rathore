# %% [markdown]
# <a href="https://colab.research.google.com/github/yatharth26bai10083-byte/Yatharth-Rathore/blob/main/VITyarthi_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = input("What electronic item you want:")
if n == "mobile":
    print("We have premium, budget mobiles, Gaming phone, Foldable phone")
    a = input("Do you want premium mobile or budget mobile:")
    if a == "premium":
        print("We have Iphone, Samsung, IQOO")
        m = input("which premium phone do you want?")


        if m == "Iphone":
            print("Iphone11")
            print("Iphone12")
            print("Iphone13")
            print("Iphone14")
            print("Iphone15")
            print("Iphone16")
            print("Iphone17")
            choice = input("Which model you want:")
            if choice == "Iphone11":
                print("iphone 11,iphone11 pro,iphone12 pro max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 11":
                    print("iphone 11 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price: 69999")
                    print("Thank you for shopping with us!")
                    #changed phone

            elif choice == "Iphone12":
                print("iphone 12,iphone12 pro,iphone12 pro max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 12":
                    print("iphone 12 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price: 79999")
                    print("Thank you for shopping with us!")
                    #phone changed
            elif choice == "Iphone13":
                print("iphone 13,iphone13 pro,iphone13 pro max,iphone13mini")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 13":
                    print("iphone 13 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price: 89999")
                    print("Thank you for shopping with us!")

                    # phone changed
            elif choice == "Iphone14":
                print("iphone 14,iphone14 pro,iphone pro14 max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 14":
                    print("iphone 14 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price: 99999")
                    print("Thank you for shopping with us!")
                    #phone chnaged
            elif choice == "Iphone15":
                print("iphone 15,iphone15 pro,iphone15 pro max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 15":
                    print("iphone 15 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price: 109999")
                    print("Thank you for shopping with us!")
                #phone changed

            elif choice == "Iphone16":
                print("iphone 16,iphone16 pro,iphone16 pro max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 16":
                    print("iphone 16 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price:119999")
                    print("Thank you for shopping with us!")


                    #phone changed
            elif choice == "Iphone17":
                print("iphone 17,iphone17 pro,iphone17 pro max")
                choose1 = input("Which model you want:")
                if choose1 == "iphone 17":
                    print("iphone 17 is available in 64GB,128GB,256GB")
                if choose1 == input("variant"):
                    print("64GB")
                    print("128GB")
                    print("256GB")
                    print("BUY NOW")
                    print("Price:129999")
                    print("Thank you for shopping with us !")

                #phone changed

        if m == "samsung":
            print("Choose a Samsung Phone:")
            print("1. Samsung Galaxy S23")
            print("2. Samsung Galaxy S24")
            print("3. Samsung Galaxy S24 Ultra")
            print("4. Samsung Galaxy A55")
            print("5. Samsung Galaxy M35")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Samsung Galaxy S23.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price:38400")
                print("Thank you for shopping with us!")

            elif choice == "2":
                print("You selected Samsung Galaxy S24.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price:49998")
                print("Thank you for shopping with us!")

            elif choice == "3":
                print("You selected Samsung Galaxy S24 Ultra.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price:69899")
                print("Thank you for shopping with us!")

            elif choice == "4":
                print("You selected Samsung Galaxy A55.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price:40000")
                print("Thank you for shopping with us!")

            elif choice == "5":
                print("You selected Samsung Galaxy M35.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price:67000")
                print("Thank you for shopping with us!")
            else:
                print("Invalid choice. Please enter a number from 1 to 5.")

        if m == "IQOO":
            print(" you Choosed an iQOO Phone:")
            print("1. iQOO Z10")
            print("2. iQOO Neo 10")
            print("3. iQOO Neo 10 Pro")
            print("4. iQOO 13")
            print("5. iQOO Z9s Pro")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected iQOO Z10.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 35000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected iQOO Neo 10.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 39999")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected iQOO Neo 10 Pro.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 49999")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected iQOO 13.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 59999")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected iQOO Z9s Pro.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 69999")
                print("Thank you for shopping with us!")
            else:
                print("Invalid choice. Please enter a number from 1 to 5.")

    if a == "budget":
        print("We have Realme, Poco, Redmi")
        m = input("which budget phone do you want?")
        if m == "Realme":
            print("Choose a Realme Phone:")
            print("1. Realme 10")
            print("2. Realme 11")
            print("3. Realme 12")
            print("4. Realme 13")
            print("5. Realme 14")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Realme 10.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Realme 11.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Realme 11.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Realme 12.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Realme 13.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Realme 14.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")

        if m == "Poco":
            print("Choose a Poco Phone:")
            print("1. Poco X5")
            print("2. Poco X6")
            print("3. Poco X7")
            print("4. Poco X8")
            print("5. Poco X9")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Poco X5.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Poco X6.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Poco X7.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Poco X8.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Poco X9.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")

        if m == "Redmi":
            print("Choose a Redmi Phone:")
            print("1. Redmi Note 12")
            print("2. Redmi Note 13")
            print("3. Redmi Note 14")
            print("4. Redmi Note 15")
            print("5. Redmi Note 16")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Redmi Note 12.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Redmi Note 13.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Redmi Note 14.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Redmi Note 15.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Redmi Note 16.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")

    if a == "gaming":
        print("We have Asus ROG, Lenovo Legion, Acer Predator")
        m = input("which gaming phone do you want?")
        if m == "Asus ROG":
            print("Choose a Asus ROG Phone:")
            print("1. Asus ROG Phone 6")
            print("2. Asus ROG Phone 7")
            print("3. Asus ROG Phone 8")
            print("4. Asus ROG Phone 9")
            print("5. Asus ROG Phone 10")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Asus ROG Phone 6.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Asus ROG Phone 7.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Asus ROG Phone 8.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Asus ROG Phone 9.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Asus ROG Phone 10.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")
        if m == "Lenovo Legion":
            print("Choose a Lenovo Legion Phone:")
            print("1. Lenovo Legion Phone Duel 2")
            print("2. Lenovo Legion Phone Duel 3")
            print("3. Lenovo Legion Phone Duel 4")
            print("4. Lenovo Legion Phone Duel 5")
            print("5. Lenovo Legion Phone Duel 6")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Lenovo Legion Phone Duel 2.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Lenovo Legion Phone Duel 3.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Lenovo Legion Phone Duel 4.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Lenovo Legion Phone Duel 5.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Lenovo Legion Phone Duel 6.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")

        if m == "Acer Predator":
            print("Choose a Acer Predator Phone:")
            print("1. Acer Predator Phone 1")
            print("2. Acer Predator Phone 2")
            print("3. Acer Predator Phone 3")
            print("4. Acer Predator Phone 4")
            print("5. Acer Predator Phone 5")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Acer Predator Phone 1.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 15000")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Acer Predator Phone 2.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 18000")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Acer Predator Phone 3.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 20000")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Acer Predator Phone 4.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 22000")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Acer Predator Phone 5.")
                print("avialabe variant 64GB,128GB, 256GB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 25000")
                print("Thank you for shopping with us!")

#laptops
if n  == "laptop":
    print("We have premium, budget laptops, Gaming laptop")
a = input("Do you want premium laptop or budget laptop:")
if a == "premium":
        print("We have Macbook, Lenovo, Asus,")
        m = input("which premium laptop do you want?")
        if m == "Macbook":
            print("Choose a Macbook:")
            print("1. Macbook Air M1")
            print("2. Macbook Air M2")
            print("3. Macbook Pro M1")
            print("4. Macbook Pro M2")
            print("5. Macbook Pro M3")

            choice = input("Enter your choice (1-5): ")

            if choice == "1":
                print("You selected Macbook Air M1.")
                print("avialabe variant 256GB,512GB, 1TB")
                choice = input("enter the variant you want:")
                print("BUY NOW")
                print("Price: 99999")
                print("Thank you for shopping with us!")
            elif choice == "2":
                print("You selected Macbook Air M2.")
                print("avialabe variant 256GB,512GB, 1TB")
                print("BUY NOW")
                print("Price: 119999")
                print("Thank you for shopping with us!")
            elif choice == "3":
                print("You selected Macbook Pro M1.")
                print("avialabe variant 256GB,512GB, 1TB")
                print("BUY NOW")
                print("Price: 139999")
                print("Thank you for shopping with us!")
            elif choice == "4":
                print("You selected Macbook Pro M2.")
                print("avialabe variant 256GB,512GB, 1TB")
                print("BUY NOW")
                print("Price: 159999")
                print("Thank you for shopping with us!")
            elif choice == "5":
                print("You selected Macbook Pro M3.")
                print("avialabe variant 256GB,512GB, 1TB")
                print("BUY NOW")
                print("Price: 179999")

            if m == "Lenovo":
                print("Choose a Lenovo Laptop:")
                print("1. Lenovo loq rtx 3050")
                print("2. Lenovo loq rtx 4050")
                print("3. Lenovo loq rtx 4060")
                print("4. Lenovo Legion rtx 5050")
                print("5. Lenovo Legion 7i")

                choice = input("Enter your choice (1-5): ")

                if choice == "1":
                    print("You selected Lenovo loq rtx 3050.")
                    print("avialabe variant 256GB,512GB, 1TB")

                    print("BUY NOW")
                    print("Price: 99999")
                    print("Thank you for shopping with us!")
                elif choice == "2":
                    print("You selected Lenovo loq rtx 4050.")
                    print("avialabe variant 256GB,512GB, 1TB")
                    print("BUY NOW")
                    print("Price: 119999")
                    print("Thank you for shopping with us!")
                elif choice == "3":
                    print("You selected Lenovo loq rtx 4060.")
                    print("avialabe variant 256GB,512GB, 1TB")
                    print("BUY NOW")
                    print("Price: 139999")
                    print("Thank you for shopping with us!")
                elif choice == "4":
                    print("You selected Lenovo Legion rtx 5050.")
                    print("avialabe variant 256GB,512GB, 1TB")
# Out:
# What electronic item you want:laptop
# We have premium, budget laptops, Gaming laptop
# Do you want premium laptop or budget laptop:premium
# We have Macbook, Lenovo, Asus,
# which premium laptop do you want?Macbook
# Choose a Macbook:
# 1. Macbook Air M1
# 2. Macbook Air M2
# 3. Macbook Pro M1
# 4. Macbook Pro M2
# 5. Macbook Pro M3
# Enter your choice (1-5): 1
# You selected Macbook Air M1.
# avialabe variant 256GB,512GB, 1TB
# enter the variant you want:1TB
# BUY NOW
# Price: 99999
# Thank you for shopping with us!
